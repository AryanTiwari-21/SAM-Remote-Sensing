# %%
# Install Gradio
# !pip install gradio -q

# %%
# Fix segment_anything installation
# !pip uninstall segment-anything -y
# !pip install git+https://github.com/facebookresearch/segment-anything.git
# Out:
# WARNING: Skipping segment-anything as it is not installed.
# ...
#   Cloning https://github.com/facebookresearch/segment-anything.git to /tmp/pip-req-build-9542077i
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/segment-anything.git /tmp/pip-req-build-9542077i
#   Resolved https://github.com/facebookresearch/segment-anything.git to commit dca509fe793f601edb92606367a655c15ac00fdf
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for segment_anything: filename=segment_anything-1.0-py3-none-any.whl size=36592 sha256=6fbe1b754255c709d4f8281d61001bf5b80dbb3506b55cfea16882bc4f2edffd
#   Stored in directory: /tmp/pip-ephem-wheel-cache-p7i00r5q/wheels/29/82/ff/04e2be9805a1cb48bec0b85b5a6da6b63f647645750a0e42d4
# Successfully built segment_anything
# ...

# %%
# Fix GroundingDINO import
import sys
sys.path.append("/content/drive/MyDrive/DLminorproject/Grounded-Segment-Anything")
sys.path.append("/content/drive/MyDrive/DLminorproject/Grounded-Segment-Anything/GroundingDINO")

# !pip install groundingdino-py -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.3/82.3 kB 5.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.8/46.8 kB 4.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.2/256.2 kB 20.2 MB/s eta 0:00:00
# ...

# %%
# Launches the UI
# %run /content/drive/MyDrive/DLminorproject/GradioApp.py
# Out:
# All patches applied ✅
# Loading SAM model...
# Using device: cuda
# SAM loaded ✅
# Loading GroundingDINO model...
# /usr/local/lib/python3.12/dist-packages/timm/models/layers/__init__.py:49: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /usr/local/lib/python3.12/dist-packages/torch/functional.py:505: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:4381.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# final text_encoder_type: bert-base-uncased
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:93: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# ...
